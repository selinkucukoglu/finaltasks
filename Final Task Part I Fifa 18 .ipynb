# %%
#Importing the libraries
import pandas as pd 
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
# %matplotlib inline
from sklearn.cluster import KMeans

# %%
#Importing the file
d = pd.read_csv("Desktop/Fifa18.csv", sep=",",encoding = "ISO-8859-1")
# Out:
# /Users/selinkucukoglu/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (23,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Getting the first 6 rows of data
d.head()

#displays us the first 6 rows of data with all the columns
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3         L. SuÌÁrez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %%
#Getting the last 6 columns of data
d.tail()

#displays us the last 6 rows of data with all the columns
# Out:
#        Unnamed: 0           Name  Age  \
# 17976       17976      A. Kelsey   17
# 17977       17977  B. Richardson   47
# 17978       17978       J. Young   17
# 17979       17979   J. Lundstram   18
# 17980       17980      L. Sackey   18
#
#                                                  Photo Nationality  \
# 17976  https://cdn.sofifa.org/48/18/players/237463.png     England
# 17977   https://cdn.sofifa.org/48/18/players/11728.png     England
# 17978  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 17979  https://cdn.sofifa.org/48/18/players/238813.png     England
# 17980  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 17976   https://cdn.sofifa.org/flags/14.png       46         63
# 17977   https://cdn.sofifa.org/flags/14.png       46         46
# 17978   https://cdn.sofifa.org/flags/42.png       46         61
# 17979   https://cdn.sofifa.org/flags/14.png       46         64
# ...

# %%
#Dimension of the dataset
d.shape

#there are 17981 rows and 75 columns in this dataset
# Out:
# (17981, 75)

# %%
#Getting the size of the dataset
d.size

#Returns size of dataframe which is equivalent to total number of elements (rows x columns)
# Out:
# 1348575

# %%
#Calculating the variance of the dataset
d.var()
# Out:
# Unnamed: 0    2.694453e+07
# Age           2.129151e+01
# Overall       4.883166e+01
# Potential     3.723684e+01
# Special       7.406640e+04
# CAM           9.761764e+01
# CB            1.486590e+02
# CDM           1.062998e+02
# CF            9.854508e+01
# CM            7.899726e+01
# ID            1.042752e+09
# LAM           9.761764e+01
# LB            9.587596e+01
# LCB           1.486590e+02
# LCM           7.899726e+01
# LDM           1.062998e+02
# LF            9.854508e+01
# LM            8.740717e+01
# LS            8.429796e+01
# LW            9.956216e+01
# LWB           8.359125e+01
# RAM           9.761764e+01
# RB            9.587596e+01
# RCB           1.486590e+02
# RCM           7.899726e+01
# RDM           1.062998e+02
# RF            9.854508e+01
# RM            8.740717e+01
# RS            8.429796e+01
# RW            9.956216e+01
# RWB           8.359125e+01
# ST            8.429796e+01
# dtype: float64

# %%
#Checking if there are any missing values
d.isnull().values.any()

#the output indicates that not every column is filled with values
# Out:
# True

# %%
#Getting the number of missing values in each column
Fifa18 = pd.read_csv("Desktop/Fifa18.csv",encoding = "ISO-8859-1")
null_columns=Fifa18.columns[Fifa18.isnull().any()]
Fifa18[null_columns].isnull().sum()

#the output below shows us the number of missing values in each column, for example in "Club" there are 248 missing values
# Out:
# Club     248
# CAM     2029
# CB      2029
# CDM     2029
# CF      2029
# CM      2029
# LAM     2029
# LB      2029
# LCB     2029
# LCM     2029
# LDM     2029
# LF      2029
# LM      2029
# LS      2029
# LW      2029
# LWB     2029
# RAM     2029
# RB      2029
# RCB     2029
# RCM     2029
# RDM     2029
# RF      2029
# RM      2029
# RS      2029
# RW      2029
# RWB     2029
# ST      2029
# dtype: int64

# %%
#Checking which rows have missing values for the LCM column specifically
Fifa18[Fifa18["LCM"].isnull()][null_columns]

#the rows displayed below shows that their values are missing for the column "LCM"
# Out:
#                               Club  CAM  CB  CDM  CF  CM  LAM  LB  LCB  LCM  \
# 4                 FC Bayern Munich  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 6                Manchester United  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 12                         Chelsea  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 18                        Juventus  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 20                AtlÌ©tico Madrid  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 29               Tottenham Hotspur  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 43                           Inter  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 68                         Arsenal  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 74                  Real Madrid CF  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 76                       AS Monaco  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# 77             Bayer 04 Leverkusen  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN
# ...

# %%
#Checking the first 6 columns of missing data
Fifa18[Fifa18.isnull().any(axis=1)][null_columns].head()

#missing values start from row number 4, meaning there are not any missing values for the first 3 rows
# Out:
#                  Club  CAM  CB  CDM  CF  CM  LAM  LB  LCB  LCM ...  RB  RCB  \
# 4    FC Bayern Munich  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 6   Manchester United  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 12            Chelsea  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 18           Juventus  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 20   AtlÌ©tico Madrid  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
#
#     RCM  RDM  RF  RM  RS  RW  RWB  ST
# 4   NaN  NaN NaN NaN NaN NaN  NaN NaN
# 6   NaN  NaN NaN NaN NaN NaN  NaN NaN
# 12  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 18  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 20  NaN  NaN NaN NaN NaN NaN  NaN NaN
#
# [5 rows x 27 columns]

# %%
#Filling missing values with "0"
d.fillna(0)
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3         L. SuÌÁrez   30
# 4               4           M. Neuer   31
# 5               5     R. Lewandowski   28
# 6               6             De Gea   26
# 7               7          E. Hazard   26
# 8               8           T. Kroos   27
# 9               9        G. HiguaÌ_n   29
# 10             10       Sergio Ramos   31
# 11             11       K. De Bruyne   26
# 12             12        T. Courtois   25
# 13             13        A. SÌÁnchez   28
# 14             14         L. Modrià   31
# 15             15            G. Bale   27
# 16             16         S. AgÌ_ero   29
# 17             17       G. Chiellini   32
# 18             18          G. Buffon   39
# 19             19          P. Dybala   23
# 20             20           J. Oblak   24
# ...

# %%
#Filling missing values with the same values
d.fillna(method ='pad')
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3         L. SuÌÁrez   30
# 4               4           M. Neuer   31
# 5               5     R. Lewandowski   28
# 6               6             De Gea   26
# 7               7          E. Hazard   26
# 8               8           T. Kroos   27
# 9               9        G. HiguaÌ_n   29
# 10             10       Sergio Ramos   31
# 11             11       K. De Bruyne   26
# 12             12        T. Courtois   25
# 13             13        A. SÌÁnchez   28
# 14             14         L. Modrià   31
# 15             15            G. Bale   27
# 16             16         S. AgÌ_ero   29
# 17             17       G. Chiellini   32
# 18             18          G. Buffon   39
# 19             19          P. Dybala   23
# 20             20           J. Oblak   24
# ...

# %%
#Checking if there are any missing values
d.isnull().values.any()

#the output indicates there are still missing values
# Out:
# True

# %%
#Checking for basic statistic for the dataset
d.describe()

#the output displays the basic statistics (count, mean, std, etc.) for each column
#25th Percentile, which is the end of the first quartile, the 50th Percentile which is the end of the second quartile (or the median) and the 75th Percentile, which is the end of the third quartile.
# Out:
#          Unnamed: 0           Age       Overall     Potential       Special  \
# count  17981.000000  17981.000000  17981.000000  17981.000000  17981.000000
# mean    8990.000000     25.144541     66.247984     71.190813   1594.095100
# std     5190.811931      4.614272      6.987965      6.102199    272.151435
# min        0.000000     16.000000     46.000000     46.000000    728.000000
# 25%     4495.000000     21.000000     62.000000     67.000000   1449.000000
# 50%     8990.000000     25.000000     66.000000     71.000000   1633.000000
# 75%    13485.000000     28.000000     71.000000     75.000000   1786.000000
# max    17980.000000     47.000000     94.000000     94.000000   2291.000000
#
#                 CAM            CB           CDM            CF            CM  \
# count  15952.000000  15952.000000  15952.000000  15952.000000  15952.000000
# mean      59.251755     55.550464     56.865283     59.030028     58.506833
# ...

# %%
#Checking for basic statistic for the column Age
d["Age"].describe()

#the output displays the basic statistics for only the column "Age"
# Out:
# count    17981.000000
# mean        25.144541
# std          4.614272
# min         16.000000
# 25%         21.000000
# 50%         25.000000
# 75%         28.000000
# max         47.000000
# Name: Age, dtype: float64

# %%
#Getting the values for the column Age
print(d['Age'].value_counts())

#all the values in the column "Age" is printed
# Out:
# 25    1522
# 23    1394
# 24    1334
# 22    1324
# 21    1286
# 20    1245
# 26    1202
# 27    1152
# 29    1121
# 19    1069
# 28    1051
# 30     804
# 18     672
# 31     671
# 33     617
# 32     506
# 34     272
# 17     258
# 35     191
# 36     136
# 37      69
# 38      36
# 39      20
# 16      13
# 40       8
# 41       3
# 43       2
# 44       2
# 47       1
# Name: Age, dtype: int64

# %%
#Printing the names of all the columns
print(d.columns.values)

#the column names in our dataset is printed below
# Out:
# ['Unnamed: 0' 'Name' 'Age' 'Photo' 'Nationality' 'Flag' 'Overall'
#  'Potential' 'Club' 'Club Logo' 'Value' 'Wage' 'Special' 'Acceleration'
#  'Aggression' 'Agility' 'Balance' 'Ball control' 'Composure' 'Crossing'
#  'Curve' 'Dribbling' 'Finishing' 'Free kick accuracy' 'GK diving'
#  'GK handling' 'GK kicking' 'GK positioning' 'GK reflexes'
#  'Heading accuracy' 'Interceptions' 'Jumping' 'Long passing' 'Long shots'
#  'Marking' 'Penalties' 'Positioning' 'Reactions' 'Short passing'
#  'Shot power' 'Sliding tackle' 'Sprint speed' 'Stamina' 'Standing tackle'
#  'Strength' 'Vision' 'Volleys' 'CAM' 'CB' 'CDM' 'CF' 'CM' 'ID' 'LAM' 'LB'
#  'LCB' 'LCM' 'LDM' 'LF' 'LM' 'LS' 'LW' 'LWB' 'Preferred Positions' 'RAM'
#  'RB' 'RCB' 'RCM' 'RDM' 'RF' 'RM' 'RS' 'RW' 'RWB' 'ST']

# %%
#Getting details about the types of columns
d.info()

#the output tells us about the types of columns: int, object, float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 75 columns):
# Unnamed: 0             17981 non-null int64
# Name                   17981 non-null object
# Age                    17981 non-null int64
# Photo                  17981 non-null object
# Nationality            17981 non-null object
# Flag                   17981 non-null object
# Overall                17981 non-null int64
# Potential              17981 non-null int64
# Club                   17733 non-null object
# Club Logo              17981 non-null object
# Value                  17981 non-null object
# Wage                   17981 non-null object
# Special                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# ...

# %%
#Displaying all the variables in the column Agility
print(d.Agility.to_string(index=False))
# Out:
# 89
#    90
#    96
#    86
#    52
#    78
#    60
#    93
#    71
#    75
#    79
#    80
#    61
#    90
#    93
#    77
#    86
#    59
#    55
#    91
#    67
#    90
#    90
#    77
#    60
#    58
#    63
#    64
#    83
#    55
#    74
#    81
#    89
#    83
#    87
#    76
#    78
#    75
#    81
#    77
#    76
#    72
#    92
#    42
#    58
#    79
#    73
#    82
#    83
#    79
#    62
#    79
#    76
#    58
#    92
#    86
#    60
#    72
#    58
#    81
#    54
#    94
#    62
#    61
#    77
#    65
#    88
#    63
#    49
#    91
#    58
#    66
#    96
#    87
#    60
#    89
#    42
#    52
#    37
#    34
#    90
#    83
#    75
#    92
#    79
#    81
#    62
#    76
#    51
#    74
#    60
#    51
#    63
#    78
#    88
#    49
#    74
#    89
#    82
#    81
#    74
#    62
#    50
#    50
#    77
#    68
#    66
#    84
#    65
#    84
#    51
#    53
#    78
#    57
#    89
#    59
#    39
#    62
#    85
#    59
#    79
#    85
#    68
#    62
#    85
# ...

# %%
#Data cleaning
d =d.drop(['Name', 'Photo','Flag', 'Club', 'Club Logo', ], axis=1)

#removing certain columns from the dataset to have a cleaner data so we can get only numerical values for clustering methods

# %%
d.head()
# Out:
#    Unnamed: 0  Age Nationality  Overall  Potential     Value     Wage  \
# 0           0   32    Portugal       94         94  âÂ95.5M  âÂ565K
# 1           1   30   Argentina       93         93   âÂ105M  âÂ565K
# 2           2   25      Brazil       92         94   âÂ123M  âÂ280K
# 3           3   30     Uruguay       92         92    âÂ97M  âÂ510K
# 4           4   31     Germany       92         92    âÂ61M  âÂ230K
#
#    Special Acceleration Aggression  ...     RB   RCB   RCM   RDM    RF    RM  \
# 0     2228           89         63  ...   61.0  53.0  82.0  62.0  91.0  89.0
# 1     2154           92         48  ...   57.0  45.0  84.0  59.0  92.0  90.0
# 2     2100           94         56  ...   59.0  46.0  79.0  59.0  88.0  87.0
# 3     2291           88         78  ...   64.0  58.0  80.0  65.0  88.0  85.0
# 4     1493           58         29  ...    NaN   NaN   NaN   NaN   NaN   NaN
#
#      RS    RW   RWB    ST
# 0  92.0  91.0  66.0  92.0
# 1  88.0  91.0  62.0  88.0
# ...

# %%
#Checking the first 6 columns of missing data
Fifa18[Fifa18.isnull().any(axis=1)][null_columns].head()
# Out:
#                  Club  CAM  CB  CDM  CF  CM  LAM  LB  LCB  LCM ...  RB  RCB  \
# 4    FC Bayern Munich  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 6   Manchester United  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 12            Chelsea  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 18           Juventus  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
# 20   AtlÌ©tico Madrid  NaN NaN  NaN NaN NaN  NaN NaN  NaN  NaN ... NaN  NaN
#
#     RCM  RDM  RF  RM  RS  RW  RWB  ST
# 4   NaN  NaN NaN NaN NaN NaN  NaN NaN
# 6   NaN  NaN NaN NaN NaN NaN  NaN NaN
# 12  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 18  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 20  NaN  NaN NaN NaN NaN NaN  NaN NaN
#
# [5 rows x 27 columns]

# %%
#Filling missing values with the mean values
d.fillna(d.mean(), inplace=True)
d.head()
# Out:
#    Unnamed: 0  Age Nationality  Overall  Potential     Value     Wage  \
# 0           0   32    Portugal       94         94  âÂ95.5M  âÂ565K
# 1           1   30   Argentina       93         93   âÂ105M  âÂ565K
# 2           2   25      Brazil       92         94   âÂ123M  âÂ280K
# 3           3   30     Uruguay       92         92    âÂ97M  âÂ510K
# 4           4   31     Germany       92         92    âÂ61M  âÂ230K
#
#    Special Acceleration Aggression    ...            RB        RCB        RCM  \
# 0     2228           89         63    ...     61.000000  53.000000  82.000000
# 1     2154           92         48    ...     57.000000  45.000000  84.000000
# 2     2100           94         56    ...     59.000000  46.000000  79.000000
# 3     2291           88         78    ...     64.000000  58.000000  80.000000
# 4     1493           58         29    ...     56.979689  55.550464  58.506833
#
# ...

# %%
#Checking if there are any missing values
d.isnull().values.any()

#the output indicates that there arent any missing values left in the dataset
# Out:
# False

# %%
d.info()

#again checking for the types of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 70 columns):
# Unnamed: 0             17981 non-null int64
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Potential              17981 non-null int64
# Value                  17981 non-null object
# Wage                   17981 non-null object
# Special                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# ...

# %%
print(d.Wage.to_string(index=False))
# Out:
# âÂ565K
# âÂ565K
# âÂ280K
# âÂ510K
# âÂ230K
# âÂ355K
# âÂ215K
# âÂ295K
# âÂ340K
# âÂ275K
# âÂ310K
# âÂ285K
# âÂ190K
# âÂ265K
# âÂ340K
# âÂ370K
# âÂ325K
# âÂ225K
# âÂ110K
# âÂ215K
#  âÂ82K
# âÂ150K
# âÂ225K
# âÂ165K
# âÂ210K
# âÂ215K
# âÂ125K
# âÂ215K
# âÂ265K
# âÂ165K
# âÂ175K
# âÂ240K
# âÂ225K
# âÂ190K
# âÂ130K
# âÂ195K
# âÂ165K
# âÂ160K
# âÂ160K
# âÂ250K
# âÂ130K
# âÂ275K
# âÂ220K
#  âÂ91K
# âÂ240K
# âÂ260K
# âÂ165K
# âÂ250K
# âÂ250K
# âÂ150K
# âÂ210K
# âÂ175K
# âÂ190K
# âÂ250K
# âÂ205K
# âÂ120K
# âÂ165K
# âÂ190K
# âÂ235K
# âÂ130K
# âÂ165K
# âÂ135K
# âÂ110K
# âÂ115K
# âÂ295K
# âÂ210K
# âÂ175K
#  âÂ94K
#  âÂ92K
#  âÂ77K
# âÂ175K
# âÂ195K
# âÂ115K
# âÂ180K
# âÂ165K
# âÂ195K
#  âÂ46K
#  âÂ61K
# âÂ155K
#  âÂ60K
# âÂ215K
# âÂ190K
# âÂ160K
# âÂ145K
# âÂ160K
# âÂ160K
# âÂ130K
# âÂ145K
#  âÂ49K
#  âÂ81K
# âÂ170K
# âÂ105K
# âÂ150K
# âÂ175K
# âÂ165K
#  âÂ36K
# âÂ115K
# âÂ175K
# âÂ195K
# âÂ120K
# ...

# %%
print(d.Acceleration.to_string(index=False))

#displays all the values for the column "Acceleration"
# Out:
# 89
#    92
#    94
#    88
#    58
#    79
#    57
#    93
#    60
#    78
#    75
#    76
#    46
#    88
#    75
#    93
#    90
#    68
#    49
#    88
#    43
#    87
#    77
#    95
#    62
#    72
#    62
#    62
#    75
#    65
#    70
#    63
#    87
#    82
#    69
#    72
#    77
#    76
#    75
#    77
#    72
#    67
#    72
#    54
#    55
#    72
#    68
#    77
#    74
#    86
#    76
#    84
#    76
#    48
#    88
#    86
#    62
#    68
#    74
#    80
#    49
#    93
#    71
#    67
#    77
#    65
#    85
#    65
#    40
#    87
#    77
#    63
#    94
#    84
#    54
#    88
#    51
#    46
#    38
#    53
#    93
#    73
#    78
#    86
#    74
#    78
#    68
#    79
#    45
#    75
#    61
#    64
#    75
#    79
#    85
#    68
#    77
#    94
#    76
#    76
#    75
#    78
#    69
#    45
#    72
#    78
#    64
#    76
#    65
#    84
#    44
#    42
#    81
#    67
#    91
#    60
#    38
#    59
#    71
#    72
#    79
#    73
#    74
#    62
#    79
# ...

# %%
d['Acceleration'].astype(str).astype(int)

#the error shows that we cannot convert the values because they are not integers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-1f14db4249e9> in <module>
# ----> 1 d['Acceleration'].astype(str).astype(int)
#       2
#       3 #the error shows that we cannot convert the values because they are not integers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
# ...

# %%
print(d.dtypes)
# Out:
# Unnamed: 0               int64
# Age                      int64
# Nationality             object
# Overall                  int64
# Potential                int64
# Value                   object
# Wage                    object
# Special                  int64
# Acceleration            object
# Aggression              object
# Agility                 object
# Balance                 object
# Ball control            object
# Composure               object
# Crossing                object
# Curve                   object
# Dribbling               object
# Finishing               object
# Free kick accuracy      object
# GK diving               object
# GK handling             object
# GK kicking              object
# GK positioning          object
# GK reflexes             object
# Heading accuracy        object
# Interceptions           object
# Jumping                 object
# Long passing            object
# Long shots              object
# Marking                 object
# ...

# %%
d =d.drop(['Value', 'Wage'], axis=1)

#removing 2 non-numerical columns from the dataset to have only numerical values for clustering methods

# %%
d.head()
# Out:
#    Unnamed: 0  Age Nationality  Overall  Potential  Special Acceleration  \
# 0           0   32    Portugal       94         94     2228           89
# 1           1   30   Argentina       93         93     2154           92
# 2           2   25      Brazil       92         94     2100           94
# 3           3   30     Uruguay       92         92     2291           88
# 4           4   31     Germany       92         92     1493           58
#
#   Aggression Agility Balance    ...            RB        RCB        RCM  \
# 0         63      89      63    ...     61.000000  53.000000  82.000000
# 1         48      90      95    ...     57.000000  45.000000  84.000000
# 2         56      96      82    ...     59.000000  46.000000  79.000000
# 3         78      86      60    ...     64.000000  58.000000  80.000000
# 4         29      52      35    ...     56.979689  55.550464  58.506833
#
#          RDM         RF         RM        RS         RW        RWB        ST
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 68 columns):
# Unnamed: 0             17981 non-null int64
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Potential              17981 non-null int64
# Special                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# ...

# %%
d =d.drop(['Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions', 'Volleys', 'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions', 'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle', 'Strength' , 'Vision', 'Preferred Positions' ], axis=1)

#removing all the other non-numerical columns from the dataset to have only numerical values for clustering methods

# %%
d.info()

#the output does not include any "object" values meaning the dataset contains only numerical values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 33 columns):
# Unnamed: 0     17981 non-null int64
# Age            17981 non-null int64
# Nationality    17981 non-null object
# Overall        17981 non-null int64
# Potential      17981 non-null int64
# Special        17981 non-null int64
# CAM            17981 non-null float64
# CB             17981 non-null float64
# CDM            17981 non-null float64
# CF             17981 non-null float64
# CM             17981 non-null float64
# ID             17981 non-null int64
# LAM            17981 non-null float64
# LB             17981 non-null float64
# LCB            17981 non-null float64
# LCM            17981 non-null float64
# LDM            17981 non-null float64
# LF             17981 non-null float64
# LM             17981 non-null float64
# LS             17981 non-null float64
# LW             17981 non-null float64
# LWB            17981 non-null float64
# ...

# %%
#Detecting outliers
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
#Detecting outliers in column Age
outlier_datapoints = detect_outlier(d["Age"])
print(outlier_datapoints)

#below displays the outliers in column "Age"
# Out:
# [39, 39, 40, 39, 40, 40, 40, 39, 39, 39, 44, 39, 44, 39, 39, 41, 39, 41, 39, 39, 39, 39, 40, 39, 39, 40, 39, 40, 39, 41, 40, 43, 39, 43, 39, 47]

# %%
#Detecting outliers with boxplot
import seaborn as sns
sns.boxplot(x=d['Age'])

#the boxplot displays the outlier values visually, any value above the age 38 is counted as an outlier

# %%
#Data Visualization
d.plot.scatter(x='Age', y='Potential', title='Correlation')

#the scatterplot belows shows us the correlation between the column "Age" and "Potential"
#there is a negative correlation between age and potential meaning the younger the age of the player will have a greater potential

# %%
#Data Visualization
d['Age'].plot.hist()

#the histogram below displays the values for the column "Age"
#the histogram tells us that the majority of the players are between 20-25 years old

# %%
d['Age'].value_counts().plot.bar()

#the plot below displays the values for the column "Age", sorting from the highest number to the lowerst
#age 25 has the most number of players, age 23 comes the second

# %%
d['Age'].value_counts().sort_index().plot.bar()

#the plot below displays the values for the column "Age" sorted by increasing age number

# %%
d['Age'].value_counts().sort_index().plot.barh()

#same plot just reverted to the side

# %%
d.groupby("Age").Age.mean().sort_values(ascending=False)[:5].plot.bar()

#the plot shows the highest 5 values in descending order

# %%
sns.scatterplot(x='Age', y='Potential', data=d)

#the seaborn scatterplot shows the correlation between columns "Age" and "Potential" 
#negative correlation meaning younger the age, the greater potential it is
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. (https://seaborn.pydata.org/)

# %%
sns.scatterplot(x='Age', y='Potential', hue='Age', data=d)

#same seaborn scatterplot except the hue parameter determines which column in the data frame should be used for colour encoding
#negative correlation meaning younger the age, the greater potential it is

# %%
sns.lineplot(data=d['Age'])

#seaborn lineplot displays the values for the column "Age"

# %%
sns.distplot(d['Age'], bins=10, kde=False)

#seaborn distplot shows the values for the column "Age"
#the majority of the players age from 20-25 years

# %%
sns.distplot(d['Age'], bins=10, kde=True)

#Kernel Density Estimation (KDE) is a way to estimate the probability density function of a continuous random variable. (https://www.tutorialspoint.com/seaborn/seaborn_kernel_density_estimates)
# Out:
# /Users/selinkucukoglu/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(d['Age'])

#seaborn countplot displaying the values for the column "Age"
#the majority of the players age from 20-25 years

# %%
#Principal Component Analysis
#Step 1: Standardize the Data
features = ['Unnamed: 0', 'Age','Overall', 'Potential', 'Special', 'CAM',
 'CB', 'CDM', 'CF', 'CM', 'ID', 'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS',
 'LW', 'LWB', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST' ] 
# Separating out the features
x = d.loc[:, features].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

#PCA is a linear dimensionality reduction technique that can be utilized for extracting information from a high-dimensional space by projecting it into a lower-dimensional sub-space. (DataCamp)
#PCA is effected by scale so you need to scale the features in your data before applying PCA (Towards Data Science)

# %%
x

#displays the values of x, which are arrays
# Out:
# array([[-1.73195448,  1.48574871,  3.97151194, ...,  3.36676158,
#          0.96400115,  3.90813075],
#        [-1.73176183,  1.05229887,  3.82840479, ...,  3.36676158,
#          0.49949385,  3.44557465],
#        [-1.73156918, -0.03132574,  3.68529763, ...,  3.15394973,
#          0.7317475 ,  2.98301855],
#        ...,
#        [ 1.73156918, -1.7651251 , -2.89763129, ..., -1.6343168 ,
#         -2.98431087, -1.52690343],
#        [ 1.73176183, -1.54840018, -2.89763129, ..., -1.6343168 ,
#         -1.35853534, -1.98945953],
#        [ 1.73195448, -1.54840018, -2.89763129, ..., -3.23040564,
#         -2.28754993, -3.14584978]])

# %%
#PCA projection to 2D
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

#The original data has many columns and the new components are just the two main dimensions of variation. (Towards Data Science)

# %%
finalDf = pd.concat([principalDf, d[['Nationality']]], axis = 1)
finalDf

#Concatenating DataFrame along axis = 1. finalDf is the final DataFrame before plotting the data. (Towards Data Science)
# Out:
#        principal component 1  principal component 2          Nationality
# 0                 -14.353725              -4.184229             Portugal
# 1                 -13.545921              -5.775797            Argentina
# 2                 -12.012555              -4.954508               Brazil
# 3                 -13.079807              -2.935568              Uruguay
# 4                  -1.567194               0.531425              Germany
# 5                 -11.591036              -3.743912               Poland
# 6                  -1.335124               0.390109                Spain
# 7                 -11.952748              -4.517140              Belgium
# 8                 -13.083795               2.118465              Germany
# 9                  -9.180200              -5.739837            Argentina
# 10                 -9.852874               5.938404                Spain
# 11                -12.651926              -1.835903              Belgium
# ...

# %%
principalDf.head(5)
#the output displays the first 5 rows of the principal dataframe
# Out:
#    principal component 1  principal component 2
# 0             -14.353725              -4.184229
# 1             -13.545921              -5.775797
# 2             -12.012555              -4.954508
# 3             -13.079807              -2.935568
# 4              -1.567194               0.531425

# %%
finalDf.head(5)
#the output displays the first 5 rows of the final dataframe
# Out:
#    principal component 1  principal component 2 Nationality
# 0             -14.353725              -4.184229    Portugal
# 1             -13.545921              -5.775797   Argentina
# 2             -12.012555              -4.954508      Brazil
# 3             -13.079807              -2.935568     Uruguay
# 4              -1.567194               0.531425     Germany

# %%
pca_breast = PCA(n_components=2)
principalComponents_breast = pca_breast.fit_transform(x)

# %%
d['Nationality'].unique()

#getting the unique values in column "Nationality"
# Out:
# array(['Portugal', 'Argentina', 'Brazil', 'Uruguay', 'Germany', 'Poland',
#        'Spain', 'Belgium', 'Chile', 'Croatia', 'Wales', 'Italy',
#        'Slovenia', 'France', 'Gabon', 'Sweden', 'Netherlands', 'Denmark',
#        'Slovakia', 'England', 'Colombia', 'Austria', 'Greece',
#        'Czech Republic', 'Costa Rica', 'Armenia', 'Bosnia Herzegovina',
#        'Ivory Coast', 'Senegal', 'Switzerland', 'Morocco', 'Guinea',
#        'Egypt', 'Algeria', 'Cameroon', 'Serbia', 'Japan', 'Turkey',
#        'Ecuador', 'Montenegro', 'Korea Republic', 'Kenya', 'Iceland',
#        'Mexico', 'Norway', 'DR Congo', 'Ukraine', 'Russia', 'Finland',
#        'Republic of Ireland', 'United States', 'Venezuela', 'Ghana',
#        'Uzbekistan', 'Nigeria', 'Canada', 'Paraguay', 'Romania',
#        'Albania', 'Burkina Faso', 'Cape Verde', 'New Zealand',
#        'Northern Ireland', 'Syria', 'Peru', 'Scotland', 'Bulgaria',
#        'Angola', 'Australia', 'South Africa', 'Jamaica', 'Tunisia',
# ...

# %%
#Visualize 2D projection
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

targets = ['Portugal', 'Argentina', 'Brazil']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Nationality'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

#plotting 2 dimensional data using the first 3 unique values from the column Nationality
#The three classes Portugal, Argentina, Brazil, when projected to a two-dimensional space, cannot be linearly separable.
#gives us good insight into how our samples are distributed among the three classes.

# %%
pca.explained_variance_ratio_

#The explained variance tells you how much information (variance) can be attributed to each of the principal components. (Towards Data Science)
# Out:
# array([0.57116548, 0.28879362])

# %%
d = d.drop(['Nationality'], axis=1)

#removing the column Nationality to obtain a dataset only with numerical values

# %%
#K-means clustering
plt.scatter(d['Age'], d['Potential'], s = 50, c = 'y') #variables you want to plot
plt.show()

#the scatter below shows the correlation between the two columns
#a negative correlation meaning the younger the age, the higher the potential

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
mms.fit(d)
data_transformed = mms.transform(d)
# Out:
# /Users/selinkucukoglu/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

#using the elbow method to find the optimal number for k, which is any point between 2 and 6

# %%
#K means with 2 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(d)
kmeans.cluster_centers_
# Out:
# array([[1.01502289e+04, 2.32989873e+01, 6.46898113e+01, 7.13621298e+01,
#         1.55890279e+03, 5.80579905e+01, 5.39026025e+01, 5.52041391e+01,
#         5.78914514e+01, 5.70128236e+01, 2.22752078e+05, 5.80579905e+01,
#         5.56639423e+01, 5.39026025e+01, 5.70128236e+01, 5.52041391e+01,
#         5.78914514e+01, 5.89908892e+01, 5.69833526e+01, 5.83269677e+01,
#         5.63797674e+01, 5.80579905e+01, 5.56639423e+01, 5.39026025e+01,
#         5.70128236e+01, 5.52041391e+01, 5.78914514e+01, 5.89908892e+01,
#         5.69833526e+01, 5.83269677e+01, 5.63797674e+01, 5.69833526e+01],
#        [5.93311219e+03, 3.00070750e+01, 7.03533455e+01, 7.07394380e+01,
#         1.68681726e+03, 6.23970008e+01, 5.98921307e+01, 6.12419468e+01,
#         6.20298664e+01, 6.24431416e+01, 1.67891789e+05, 6.23970008e+01,
#         6.04463241e+01, 5.98921307e+01, 6.24431416e+01, 6.12419468e+01,
#         6.20298664e+01, 6.28685861e+01, 6.14202544e+01, 6.20790888e+01,
# ...

# %%
plt.scatter(d['Age'], d['Potential'], c = 'b')
plt.scatter(2.32989873e+01 , 3.00070750e+01, s=200, c='g', marker='s')
plt.scatter(7.13621298e+01, 7.07394380e+01, s=200, c='r', marker='s')
plt.show()

# %%
#Mean shift clustering
from sklearn.cluster import MeanShift
from sklearn.datasets.samples_generator import make_blobs
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#As opposed to K-Means, when using Mean Shift, you don’t need to know the number of categories (clusters) beforehand. (Towards Data Science)

# %%
clusters = [[2.32989873e+01,3.00070750e+01,1],[6.46898113e+01,7.03533455e+01,1],[5.52041391e+01,6.12419468e+01,1]]
X, _ = make_blobs(n_samples = 150, centers = clusters, cluster_std = 0.60)

#generating data

# %%
ms = MeanShift()
ms.fit(X)
cluster_centers = ms.cluster_centers_

#store the coordinates for the cluster centers

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2], marker='o')
ax.scatter(cluster_centers[:,0], cluster_centers[:,1], cluster_centers[:,2], marker='x', color='red', s=300, linewidth=5, zorder=10)
plt.show()

#plot the data points and centroids in a 3D graph
